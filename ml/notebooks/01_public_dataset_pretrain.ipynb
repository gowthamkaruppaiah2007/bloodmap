# %% [markdown]
# # 01. Public Dataset Bootstrap & Pre-training
#
# This notebook demonstrates bootstrapping the BloodMap AI donor matcher model with a public Kaggle blood donation dataset before live user interaction data is accumulated.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb

print("XGBoost version:", xgb.__version__)
# Synthesize public dataset format
np.random.seed(42)
data = {
    'recency_months': np.random.randint(1, 24, 500),
    'frequency_donations': np.random.randint(1, 15, 500),
    'time_since_first_donation': np.random.randint(6, 60, 500),
    'donated_in_march': np.random.choice([0, 1], p=[0.75, 0.25], size=500)
}
df = pd.DataFrame(data)
print(df.head())
